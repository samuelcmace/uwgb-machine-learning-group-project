# %%
import pandas as pd

# %%
dataframe = pd.read_csv("./tariff_data_cleaned.csv")

# %%
dataframe.head(20)
# Out:
#                 Country  US 2024 Deficit  US 2024 Exports  \
# 0           Afghanistan            -11.1             11.4
# 1               Albania             13.4            141.7
# 2               Algeria          -1447.1           1014.5
# 3               Andorra              1.5              4.9
# 4                Angola          -1186.9            682.4
# 5              Anguilla             71.3             72.5
# 6   Antigua and Barbuda            550.0            573.8
# 7             Argentina           2078.8           9171.0
# 8               Armenia             39.2            160.8
# 9                 Aruba            714.8            725.5
# 10            Australia          17907.8          34593.3
# 11           Azerbaijan             97.3            255.1
# 12              Bahamas           3847.4           5639.7
# 13              Bahrain            441.9           1646.2
# 14           Bangladesh          -6151.8           2214.0
# ...
